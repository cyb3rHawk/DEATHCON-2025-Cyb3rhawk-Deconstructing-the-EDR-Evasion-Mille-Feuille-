# %% [markdown]
# # Excluding MSNT_SystemTrace from the results

# %%
from threat_hunting_toolkit import ThreatHunter
import json

# Load and filter
hunter = ThreatHunter('byovd_ss.json', auto_analyze=False)

filtered = [e for e in hunter.data 
            if hunter._extract_fields(e)['provider_name'] != 'MSNT_SystemTrace']

# Save
with open('BYOVD_SS_MSNT_SystemTrace_REMOVED.json', 'w') as f:
    for event in filtered:
        f.write(json.dumps(event, default=str) + '\n')

print(f"✓ Saved {len(filtered):,} events (removed {len(hunter.data) - len(filtered):,})")
# Out:
# ================================================================================
# THREAT HUNTING TOOLKIT
# ================================================================================
# [*] Loading: byovd_ss.json
# [*] Loading as JSONL...
# [+] Loaded JSONL: 3,063,819 records
# ✓ Saved 5,322 events (removed 3,058,497)

# %% [markdown]
# ---
# **How many providers do we have?**

# %%
from threat_hunting_toolkit import ThreatHunter

hunter = ThreatHunter("BYOVD_SS_MSNT_SystemTrace_REMOVED.json")

"""
byovd_ss.json has all events and it is about 1.5 GB. So, we will be removing the kernel logs and investigating the rest. Please use this JSON file later for your research
"""
# Out:
# ================================================================================
# THREAT HUNTING TOOLKIT
# ================================================================================
# [*] Loading: BYOVD_SS_MSNT_SystemTrace_REMOVED.json
# [*] Loading as JSONL...
# [+] Loaded JSONL: 5,322 records
# [*] Building hierarchy...
# [+] Hierarchy built: 6 providers
#
# ================================================================================
# DATA OVERVIEW
# ================================================================================
#
# Total Events:     5,322
# Providers:        6
# Unique Tasks:     26
#
# --------------------------------------------------------------------------------
# PROVIDERS (by event volume)
# --------------------------------------------------------------------------------
#   Microsoft-Windows-Kernel-Audit-API-Calls             3,570 ( 67.1%) | 1 tasks
#   Microsoft-Windows-Kernel-Registry                      693 ( 13.0%) | 1 tasks
#   Microsoft-Windows-Sysmon                               602 ( 11.3%) | 14 tasks
#   Microsoft-Windows-CodeIntegrity                        245 (  4.6%) | 6 tasks
#   Microsoft-Windows-Kernel-File                          199 (  3.7%) | 2 tasks
#   Microsoft-Windows-Kernel-Process                        13 (  0.2%) | 2 tasks
#
# Unique Process IDs: 62
# Process IDs: [4, 92, 272, 440, 556, 652, 700, 704, 756, 820, 912, 968, 1096, 1112, 1160, 1404, 1536, 1632, 1640, 2040, 2144, 2176, 2192, 2320, 2496, 2516, 2648, 2816, 3304, 3528, 3700, 3804, 3812, 3856, 4056, 4072, 4200, 4288, 4432, 4496, 4528, 4636, 4824, 5000, 5140, 5156, 5172, 5468, 5532, 5796, 6760, 6796, 6872, 6932, 7100, 7224, 7336, 7588, 7660, 7848, 7952, 7968]
# '\nbyovd_ss.json has all events and it is about 1.5 GB. So, we will be removing the kernel logs and investigating the rest. Please use this JSON file later for your research\n'

# %%
hunter._provider_hierarchy
# Out:
# defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>()>,
#             {'Microsoft-Windows-Kernel-File': defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'NameCreate': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'NameDelete': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}})}),
#              'Microsoft-Windows-Kernel-Audit-API-Calls': defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'NO_TASK': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}})}),
#              'Microsoft-Windows-Sysmon': defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'File created (rule: FileCreate) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Image loaded (rule: ImageLoad) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Registry object added or deleted (rule: RegistryEvent) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Process accessed (rule: ProcessAccess) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Process terminated (rule: ProcessTerminate) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Registry value set (rule: RegistryEvent) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'File Delete logged (rule: FileDeleteDetected) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Process Create (rule: ProcessCreate) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'RawAccessRead detected (rule: RawAccessRead) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'File Block Executable (rule: FileBlockExecutable) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Driver loaded (rule: DriverLoad) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Dns query (rule: DnsQuery) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'File stream created (rule: FileCreateStreamHash) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'Clipboard changed (rule: ClipboardChange) ': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}})}),
#              'Microsoft-Windows-Kernel-Process': defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'ProcessStop': defaultdict(set,
#                                       {'NO_EVENT_NAME': {2}}),
#                           'ProcessStart': defaultdict(set,
#                                       {'NO_EVENT_NAME': {1}})}),
#              'Microsoft-Windows-CodeIntegrity': defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'GetFileCache': defaultdict(set,
#                                       {'NO_EVENT_NAME': {1, 2}}),
#                           'ValidateImageHeader': defaultdict(set,
#                                       {'NO_EVENT_NAME': {1, 2}}),
#                           'ValidateFileHash': defaultdict(set,
#                                       {'NO_EVENT_NAME': {1, 2}}),
#                           'FileHashFoundInImageCertificate': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}}),
#                           'ValidatePageHash': defaultdict(set,
#                                       {'NO_EVENT_NAME': {1, 2}}),
#                           'PageHashFoundInImageCertificate': defaultdict(set,
#                                       {'NO_EVENT_NAME': {0}})}),
#              'Microsoft-Windows-Kernel-Registry': defaultdict(<function threat_hunting_toolkit.ThreatHunter._build_hierarchy.<locals>.<lambda>.<locals>.<lambda>()>,
#                          {'NO_TASK': defaultdict(set,
#                                       {'NO_EVENT_NAME': {40}})})})

# %%
hunter.lookup_field('GrantedAccess')
# Out:
# [*] Discovering all fields in dataset...
# [+] Discovered 8 header fields and 105 property fields
#
# ================================================================================
# FIELD LOOKUP: GrantedAccess
# ================================================================================
#
# 📍 Location: properties (event-specific data)
# Occurrences: 242 events (4.55% coverage)
#
# Sample values:
#   1. 00101000
#   2. 00100000
#   3. 00140000
#   4. FFFF1F00
#   5. 00001000
#
# 💡 How to search:
#   hunter.search('GrantedAccess')  # Universal search
#   hunter.unique_values('GrantedAccess', location='properties')
#
# 🔍 Found in providers: Microsoft-Windows-Sysmon
# {'location': 'properties',
#  'field': 'GrantedAccess',
#  'count': 242,
#  'coverage': 4.547162720781661,
#  'samples': ['00101000', '00100000', '00140000', 'FFFF1F00', '00001000'],
#  'providers': ['Microsoft-Windows-Sysmon']}

# %%
# To discover all fields you can use below query. You can also use hunter.lookup_field('field_name'). Below is for GrantedAccess
print("Discovering GrantedAccess event structure...")
sample_events = hunter.search('GrantedAccess')
if sample_events:
    first = sample_events[0] if isinstance(sample_events, list) else next(iter(sample_events), None)
    if first:
        print(f"Provider: {first.get('header', {}).get('provider_name')}")
        print(f"Event ID: {first.get('header', {}).get('event_id')}")
        print(f"Task: {first.get('header', {}).get('task_name')}")
        print(f"Properties keys: {list(first.get('properties', {}).keys())}")
# Out:
# Discovering GrantedAccess event structure...
#
# [*] Searching for 'GrantedAccess' across all fields...
# [+] Found 242 events containing 'GrantedAccess'
#
# Showing first 20 matches:
#
#   1. [2025-10-30 03:47:28Z] PID:3856
#
#   2. [2025-10-30 03:47:28Z] PID:3856
#
#   3. [2025-10-30 03:47:28Z] PID:3856
#
#   4. [2025-10-30 03:47:28Z] PID:3856
#
#   5. [2025-10-30 03:47:28Z] PID:3856
#
#   6. [2025-10-30 03:47:28Z] PID:3856
#
#   7. [2025-10-30 03:47:28Z] PID:3856
#
#   8. [2025-10-30 03:47:28Z] PID:3856
#
#   9. [2025-10-30 03:47:28Z] PID:3856
#
#   10. [2025-10-30 03:47:28Z] PID:3856
#
#   11. [2025-10-30 03:47:28Z] PID:3856
#
#   12. [2025-10-30 03:47:28Z] PID:3856
#
#   13. [2025-10-30 03:47:28Z] PID:3856
#
#   14. [2025-10-30 03:47:28Z] PID:3856
#
#   15. [2025-10-30 03:47:28Z] PID:3856
#
#   16. [2025-10-30 03:47:28Z] PID:3856
#
#   17. [2025-10-30 03:47:28Z] PID:3856
#
#   18. [2025-10-30 03:47:33Z] PID:3856
#
#   19. [2025-10-30 03:47:33Z] PID:3856
#
#   20. [2025-10-30 03:47:33Z] PID:3856
#
# ... and 222 more results not displayed
# 💡 Tip: All 242 results are stored in your variable.
#          Use display_limit to show more: search('term', display_limit=50)
# Provider: Microsoft-Windows-Sysmon
# Event ID: 10
# Task: Process accessed (rule: ProcessAccess)
# Properties keys: ['CallTrace', 'GrantedAccess', 'RuleName', 'SourceImage', 'SourceProcessGUID', 'SourceProcessId', 'SourceThreadId', 'SourceUser', 'TargetImage', 'TargetProcessGUID', 'TargetProcessId', 'TargetUser', 'UtcTime']

# %% [markdown]
# ---
# **How many different events do we have for each provider?**

# %%
from collections import defaultdict

event_catalog = defaultdict(lambda: defaultdict(lambda: defaultdict(set)))

for provider, tasks in hunter._event_counts.items():
    for task_name, events in tasks.items():
        for event_name, details in events.items():
            event_ids = details if isinstance(details, set) else {details.get('event_id')}
            event_catalog[provider][task_name][event_name].update(event_ids)

for provider in sorted(event_catalog.keys()):
    print(f"\n{provider}")
    for task_name in sorted(event_catalog[provider].keys()):
        rule = task_name.split('(rule:')[1].split(')')[0].strip() if '(rule:' in task_name else '-'
        for event_name, event_ids in event_catalog[provider][task_name].items():
            ids = sorted([e for e in event_ids if e is not None])
            event_str = f"Event: {event_name}" if event_name != 'NO_EVENT_NAME' else ""
            print(f"  Task: {task_name:<50} Rule: {rule:<25} IDs: {ids} {event_str}")
# Out:
# Microsoft-Windows-CodeIntegrity
#   Task: FileHashFoundInImageCertificate                    Rule: -                         IDs: [3009] Event: ID:3009|Name:NO_EVENT_NAME|Op:0
#   Task: GetFileCache                                       Rule: -                         IDs: [3040] Event: ID:3040|Name:NO_EVENT_NAME|Op:1
#   Task: GetFileCache                                       Rule: -                         IDs: [3041] Event: ID:3041|Name:NO_EVENT_NAME|Op:2
#   Task: PageHashFoundInImageCertificate                    Rule: -                         IDs: [3007] Event: ID:3007|Name:NO_EVENT_NAME|Op:0
#   Task: ValidateFileHash                                   Rule: -                         IDs: [3015] Event: ID:3015|Name:NO_EVENT_NAME|Op:1
#   Task: ValidateFileHash                                   Rule: -                         IDs: [3016] Event: ID:3016|Name:NO_EVENT_NAME|Op:2
#   Task: ValidateImageHeader                                Rule: -                         IDs: [3038] Event: ID:3038|Name:NO_EVENT_NAME|Op:1
#   Task: ValidateImageHeader                                Rule: -                         IDs: [3039] Event: ID:3039|Name:NO_EVENT_NAME|Op:2
#   Task: ValidatePageHash                                   Rule: -                         IDs: [3017] Event: ID:3017|Name:NO_EVENT_NAME|Op:1
#   Task: ValidatePageHash                                   Rule: -                         IDs: [3018] Event: ID:3018|Name:NO_EVENT_NAME|Op:2
#
# Microsoft-Windows-Kernel-Audit-API-Calls
#   Task: NO_TASK                                            Rule: -                         IDs: [5] Event: ID:5|Name:NO_EVENT_NAME|Op:0
#   Task: NO_TASK                                            Rule: -                         IDs: [6] Event: ID:6|Name:NO_EVENT_NAME|Op:0
#   Task: NO_TASK                                            Rule: -                         IDs: [3] Event: ID:3|Name:NO_EVENT_NAME|Op:0
#   Task: NO_TASK                                            Rule: -                         IDs: [1] Event: ID:1|Name:NO_EVENT_NAME|Op:0
#   Task: NO_TASK                                            Rule: -                         IDs: [2] Event: ID:2|Name:NO_EVENT_NAME|Op:0
#
# Microsoft-Windows-Kernel-File
#   Task: NameCreate                                         Rule: -                         IDs: [10] Event: ID:10|Name:NO_EVENT_NAME|Op:0
#   Task: NameDelete                                         Rule: -                         IDs: [11] Event: ID:11|Name:NO_EVENT_NAME|Op:0
#
# Microsoft-Windows-Kernel-Process
#   Task: ProcessStart                                       Rule: -                         IDs: [1] Event: ID:1|Name:NO_EVENT_NAME|Op:1
#   Task: ProcessStop                                        Rule: -                         IDs: [2] Event: ID:2|Name:NO_EVENT_NAME|Op:2
#
# Microsoft-Windows-Kernel-Registry
#   Task: NO_TASK                                            Rule: -                         IDs: [9] Event: ID:9|Name:NO_EVENT_NAME|Op:40
#
# Microsoft-Windows-Sysmon
#   Task: Clipboard changed (rule: ClipboardChange)          Rule: ClipboardChange           IDs: [24] Event: ID:24|Name:NO_EVENT_NAME|Op:0
#   Task: Dns query (rule: DnsQuery)                         Rule: DnsQuery                  IDs: [22] Event: ID:22|Name:NO_EVENT_NAME|Op:0
#   Task: Driver loaded (rule: DriverLoad)                   Rule: DriverLoad                IDs: [6] Event: ID:6|Name:NO_EVENT_NAME|Op:0
#   Task: File Block Executable (rule: FileBlockExecutable)  Rule: FileBlockExecutable       IDs: [27] Event: ID:27|Name:NO_EVENT_NAME|Op:0
#   Task: File Delete logged (rule: FileDeleteDetected)      Rule: FileDeleteDetected        IDs: [26] Event: ID:26|Name:NO_EVENT_NAME|Op:0
#   Task: File created (rule: FileCreate)                    Rule: FileCreate                IDs: [11] Event: ID:11|Name:NO_EVENT_NAME|Op:0
#   Task: File stream created (rule: FileCreateStreamHash)   Rule: FileCreateStreamHash      IDs: [15] Event: ID:15|Name:NO_EVENT_NAME|Op:0
#   Task: Image loaded (rule: ImageLoad)                     Rule: ImageLoad                 IDs: [7] Event: ID:7|Name:NO_EVENT_NAME|Op:0
#   Task: Process Create (rule: ProcessCreate)               Rule: ProcessCreate             IDs: [1] Event: ID:1|Name:NO_EVENT_NAME|Op:0
#   Task: Process accessed (rule: ProcessAccess)             Rule: ProcessAccess             IDs: [10] Event: ID:10|Name:NO_EVENT_NAME|Op:0
#   Task: Process terminated (rule: ProcessTerminate)        Rule: ProcessTerminate          IDs: [5] Event: ID:5|Name:NO_EVENT_NAME|Op:0
#   Task: RawAccessRead detected (rule: RawAccessRead)       Rule: RawAccessRead             IDs: [9] Event: ID:9|Name:NO_EVENT_NAME|Op:0
#   Task: Registry object added or deleted (rule: RegistryEvent)  Rule: RegistryEvent             IDs: [12] Event: ID:12|Name:NO_EVENT_NAME|Op:0
#   Task: Registry value set (rule: RegistryEvent)           Rule: RegistryEvent             IDs: [13] Event: ID:13|Name:NO_EVENT_NAME|Op:0

# %% [markdown]
# ---
# ## Can you find signs of suspicious driver or service activity? Where? Which logs?

# %%
print("--- Investigating Driver Loads (Sysmon EID 6) ---")
driver_loads = hunter.search(
    provider_name="Microsoft-Windows-Sysmon",
    event_id=6,
)
# Out:
# --- Investigating Driver Loads (Sysmon EID 6) ---
#
# [*] Found 2 matching events
#   1. [2025-10-30 03:47:34Z] PID:3856 - Driver loaded (rule: DriverLoad)
#   2. [2025-10-30 03:48:20Z] PID:3856 - Driver loaded (rule: DriverLoad)

# %%
"""
Registry events with Kernel level Drivers
"""
hunter.search(Details="0x00000001")
# Out:
# [*] Found 4 matching events
#   1. [2025-10-30 03:47:33Z] PID:3856 - Registry value set (rule: RegistryEvent)
#   2. [2025-10-30 03:47:33Z] PID:3856 - Registry value set (rule: RegistryEvent)
#   3. [2025-10-30 03:48:09Z] PID:3856 - Registry value set (rule: RegistryEvent)
#   4. [2025-10-30 03:48:09Z] PID:3856 - Registry value set (rule: RegistryEvent)
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 13,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry value set (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Details': 'DWORD (0x00000001)',
#    'EventType': 'SetValue',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    'ProcessGuid': '{39898580-DB6A-6902-0B00-000000000300}',
#    'ProcessId': 652,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\NSecKrnl\\Type',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.765'},
#   'property_types': {'Details': 'STRINGW',
#    'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 13,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry value set (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Details': 'DWORD (0x00000001)',
#    'EventType': 'SetValue',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    'ProcessGuid': '{39898580-DB6A-6902-0B00-000000000300}',
#    'ProcessId': 652,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\NSecKrnl\\ErrorControl',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.765'},
#   'property_types': {'Details': 'STRINGW',
#    'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 13,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry value set (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:48:09Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Details': 'DWORD (0x00000001)',
#    'EventType': 'SetValue',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    'ProcessGuid': '{39898580-DB6A-6902-0B00-000000000300}',
#    'ProcessId': 652,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\changed_to_exe\\Type',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:48:09.827'},
#   'property_types': {'Details': 'STRINGW',
#    'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 13,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry value set (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:48:09Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Details': 'DWORD (0x00000001)',
#    'EventType': 'SetValue',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    'ProcessGuid': '{39898580-DB6A-6902-0B00-000000000300}',
#    'ProcessId': 652,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\changed_to_exe\\ErrorControl',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:48:09.827'},
#   'property_types': {'Details': 'STRINGW',
#    'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}}]

# %% [markdown]
#  ---
#  **What are the logs associated with that driver?**
#
# The two most important logs associated with NSecKrnl.sys are the registry event that created it (above) and the Sysmon Event 6 log that shows the kernel successfully loading it into memory.

# %%
print("--- Investigating Driver Loads (Sysmon EID 6) ---")
driver_loads = hunter.search(provider_name="Microsoft-Windows-Sysmon", event_id=6, display_limit=10)
discovered_driver_log = driver_loads[0]  # Store the suspicious log
print("\n--- Investigating 'NSecKrnl.sys' ---")
driver_service_events = hunter.registry_key("NSecKrnl") # Uses regiatry_key to get all events related to that service
# Out:
# --- Investigating Driver Loads (Sysmon EID 6) ---
#
# [*] Found 2 matching events
#   1. [2025-10-30 03:47:34Z] PID:3856 - Driver loaded (rule: DriverLoad)
#   2. [2025-10-30 03:48:20Z] PID:3856 - Driver loaded (rule: DriverLoad)
#
# --- Investigating 'NSecKrnl.sys' ---
#
# ================================================================================
# REGISTRY OPERATIONS
# Filtered by: NSecKrnl
# ================================================================================
# Total operations: 699
# Unique registry keys: 6
#
# Top 10 Most Accessed Keys:
#        1x - HKLM\System\CurrentControlSet\Services\NSecKrnl
#        1x - HKLM\System\CurrentControlSet\Services\NSecKrnl\Type
#        1x - HKLM\System\CurrentControlSet\Services\NSecKrnl\Start
#        1x - HKLM\System\CurrentControlSet\Services\NSecKrnl\ErrorControl
#        1x - HKLM\System\CurrentControlSet\Services\NSecKrnl\ImagePath
#        1x - HKLM\System\CurrentControlSet\Services\NSecKrnl\DisplayName
#
# Processes accessing registry: [652, 756, 2648, 3528, 3856]

# %% [markdown]
# The log above shows the main key being created: **HKLM\System\CurrentControlSet\Services\NSecKrnl**.
#
# Other Sysmon Event 13 logs from the same process (PID 652) show the creation of its associated values, such as:
#
# HKLM\System\CurrentControlSet\Services\NSecKrnl\ImagePath
#
# HKLM\System\CurrentControlSet\Services\NSecKrnl\Type (set to 1, meaning kernel driver)
#
# HKLM\System\CurrentControlSet\Services\NSecKrnl\Start (set to 2, meaning auto-start)
#
# HKLM\System\CurrentControlSet\Services\NSecKrnl\DisplayName

# %% [markdown]
# ---
# **Can you identify the driver registered by Nsec-Killer.exe?**
#
# The NSec-Killer.exe tool did not register the driver directly. It used the Windows Service Manager (services.exe, PID 652) to register a driver located at c:\Users\cyb3r\Downloads\NSecKrnl.sys.
# This can be confirmed by the Sysmon Event 13 log, which shows services.exe setting the ImagePath (the path to the driver file) for the new service.
#
# **Crude way:**
#
# **event_id:1**
#     Nsec-Killer.exe, note the ProcessGuid and ProcessId
#     cmd.exe --> nsec-killer.exe (we can get the parent) event id:7
#     Image (nsec-killer.exe) - ProcessGuid will be same as above and you should be able to find driver name in ImageLoaded(nseckrnl) To confirm by -
# **event_id:12**
#     Image (services.exe) adds registry TargetObject (nseckrnl)
# **event_id:10** - soruceimage (services.exe)({39898580-DB6A-6902-0B00-000000000300}) accessing targetimage (nsec-killer.exe)

# %%
print("\n[Link 1] Finding the attacker process (Sysmon EID 1)...")
attacker_log = hunter.search(provider_name="Microsoft-Windows-Sysmon", event_id=1, Image="NSec-Killer.exe")[0]
hunter.show(attacker_log)
attacker_pid, attacker_guid = attacker_log.get("properties", {}).get("ProcessId"), attacker_log.get("properties", {}).get("ProcessGuid")
print(f"--- [+] Artifact Discovered: ProcessGuid = {attacker_guid} ---")
# Out:
# [Link 1] Finding the attacker process (Sysmon EID 1)...
#
# [*] Found 1 matching events
#   1. [2025-10-30 03:47:33Z] PID:3856 - Process Create (rule: ProcessCreate)
#
# ================================================================================
# EVENT DETAILS
# ================================================================================
# Timestamp:    2025-10-30 03:47:33Z
# Provider:     Microsoft-Windows-Sysmon
# Task:         Process Create (rule: ProcessCreate)
# Event ID:     1 | Opcode: 0
# Process ID:   3856 | Thread ID: 5992
#
# Properties:
#   CommandLine               : NSec-Killer.exe  -n msmpeng.exe
#   Company                   : -
#   CurrentDirectory          : c:\Users\cyb3r\Downloads\
#   Description               : -
#   FileVersion               : -
#   Hashes                    : SHA1=736230F44614A33720C3D60E35B2E314DE0C9E8C,MD5=858505745A6AB5D5C3516FC007895476,SHA256=889A707...
#   Image                     : C:\Users\cyb3r\Downloads\NSec-Killer.exe
#   IntegrityLevel            : High
#   LogonGuid                 : {39898580-DB88-6902-2284-030000000000}
#   LogonId                   : 2284030000000000
#   OriginalFileName          : -
#   ParentCommandLine         : "C:\Windows\system32\cmd.exe"
#   ParentImage               : C:\Windows\System32\cmd.exe
#   ParentProcessGuid         : {39898580-DC27-6902-B300-000000000300}
#   ParentProcessId           : 2176
#   ParentUser                : DESKTOP-3AERCN7\cyb3r
#   ProcessGuid               : {39898580-DFD5-6902-0001-000000000300}
#   ProcessId                 : 6872
#   Product                   : -
#   RuleName                  : -
#   TerminalSessionId         : 1
#   User                      : DESKTOP-3AERCN7\cyb3r
#   UtcTime                   : 2025-10-30 03:47:33.687
# ================================================================================
# --- [+] Artifact Discovered: ProcessGuid = {39898580-DFD5-6902-0001-000000000300} ---

# %%
"""
We are checking for the SourceProcessGUID

"""

hunter.search(SourceProcessGUID = '{39898580-DB6A-6902-0B00-000000000300}',
              event_id =10)
# Out:
# [*] Found 4 matching events
#   1. [2025-10-30 03:47:33Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   2. [2025-10-30 03:48:09Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   3. [2025-10-30 03:48:34Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   4. [2025-10-30 03:48:34Z] PID:3856 - Process accessed (rule: ProcessAccess)
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\Windows\\system32\\services.exe+3643f|C:\\Windows\\system32\\services.exe+25774|C:\\Windows\\system32\\services.exe+254df|C:\\Windows\\system32\\services.exe+5a03a|C:\\Windows\\system32\\services.exe+5a851|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7b253|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7a022|C:\\Windows\\SYSTEM32\\RPCRT4.dll+1e09a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+5dd7a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+58f88|C:\\Windows\\SYSTEM32\\RPCRT4.dll+3a1a6|C:\\Windows\\SYSTEM32\\RPCRT4.dll+39af8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+472bf|C:\\Windows\\SYSTEM32\\RPCRT4.dll+466c8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+45cb1|C:\\Windows\\SYSTEM32\\RPCRT4.dll+4571e|C:\\Windows\\SYSTEM32\\RPCRT4.dll+49e32|C:\\Windows\\SYSTEM32\\ntdll.dll+20330|C:\\Windows\\SYSTEM32\\ntdll.dll+52f76|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\services.exe',
#    'SourceProcessGUID': '{39898580-DB6A-6902-0B00-000000000300}',
#    'SourceProcessId': 652,
#    'SourceThreadId': 7896,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.781'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:48:09Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\Windows\\system32\\services.exe+3643f|C:\\Windows\\system32\\services.exe+25774|C:\\Windows\\system32\\services.exe+254df|C:\\Windows\\system32\\services.exe+5a03a|C:\\Windows\\system32\\services.exe+5a851|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7b253|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7a022|C:\\Windows\\SYSTEM32\\RPCRT4.dll+1e09a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+5dd7a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+58f88|C:\\Windows\\SYSTEM32\\RPCRT4.dll+3a1a6|C:\\Windows\\SYSTEM32\\RPCRT4.dll+39af8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+472bf|C:\\Windows\\SYSTEM32\\RPCRT4.dll+466c8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+45cb1|C:\\Windows\\SYSTEM32\\RPCRT4.dll+4571e|C:\\Windows\\SYSTEM32\\RPCRT4.dll+49e32|C:\\Windows\\SYSTEM32\\ntdll.dll+20330|C:\\Windows\\SYSTEM32\\ntdll.dll+52f76|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\services.exe',
#    'SourceProcessGUID': '{39898580-DB6A-6902-0B00-000000000300}',
#    'SourceProcessId': 652,
#    'SourceThreadId': 7896,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'C:\\Windows\\system32\\sc.exe',
#    'TargetProcessGUID': '{39898580-DFF9-6902-0201-000000000300}',
#    'TargetProcessId': 272,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:48:09.827'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:48:34Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9e974|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+5b3d3|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+58963|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+1e2a0|C:\\Windows\\system32\\services.exe+151e7|C:\\Windows\\system32\\services.exe+9473|C:\\Windows\\system32\\services.exe+13959|C:\\Windows\\system32\\services.exe+135ea|C:\\Windows\\system32\\services.exe+12b38|C:\\Windows\\system32\\services.exe+1251a|C:\\Windows\\system32\\services.exe+5fa82|C:\\Windows\\SYSTEM32\\ntdll.dll+7868b|C:\\Windows\\SYSTEM32\\ntdll.dll+10ebc|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': 'FFFF1F00',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\services.exe',
#    'SourceProcessGUID': '{39898580-DB6A-6902-0B00-000000000300}',
#    'SourceProcessId': 652,
#    'SourceThreadId': 7896,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'TargetProcessGUID': '{39898580-E012-6902-0401-000000000300}',
#    'TargetProcessId': 756,
#    'TargetUser': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:48:34.153'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:48:34Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9e134|C:\\Windows\\SYSTEM32\\RPCRT4.dll+4ee34|C:\\Windows\\system32\\services.exe+1e24|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7b253|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7a022|C:\\Windows\\SYSTEM32\\RPCRT4.dll+1e09a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+5dd7a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+58f88|C:\\Windows\\SYSTEM32\\RPCRT4.dll+3a1a6|C:\\Windows\\SYSTEM32\\RPCRT4.dll+39af8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+472bf|C:\\Windows\\SYSTEM32\\RPCRT4.dll+466c8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+45cb1|C:\\Windows\\SYSTEM32\\RPCRT4.dll+4571e|C:\\Windows\\SYSTEM32\\RPCRT4.dll+49e32|C:\\Windows\\SYSTEM32\\ntdll.dll+20330|C:\\Windows\\SYSTEM32\\ntdll.dll+52f76|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\services.exe',
#    'SourceProcessGUID': '{39898580-DB6A-6902-0B00-000000000300}',
#    'SourceProcessId': 652,
#    'SourceThreadId': 7836,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'TargetProcessGUID': '{39898580-E012-6902-0401-000000000300}',
#    'TargetProcessId': 756,
#    'TargetUser': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:48:34.340'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}}]

# %% [markdown]
# ---
# **How does the process spawned by the driver(Nsec-Killer) and Registry logs correlate?**
#
# This is an indirect correlation. The NSec-Killer.exe process (PID 6872) does not write the registry logs itself. It uses the legitimate Windows Service Manager (services.exe, PID 652) to do the work.

# %%
from collections import defaultdict
target_data = defaultdict(lambda: {'count': 0, 'guids': set(), 'pids': set(), 'guid_counts': defaultdict(int)})
for e in hunter.search(provider_name='Microsoft-Windows-Sysmon', event_id=10):
    p = e.get('properties', {}); img, guid, pid = p.get('TargetImage'), p.get('TargetProcessGUID'), p.get('TargetProcessId')
    if img and guid and pid: target_data[img]['count'] += 1; target_data[img]['guids'].add(guid); target_data[img]['pids'].add(pid); target_data[img]['guid_counts'][guid] += 1
# Out:
# [*] Found 242 matching events
# [*] Showing first 20 of 242 results
#   1. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   2. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   3. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   4. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   5. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   6. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   7. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   8. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   9. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   10. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   11. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   12. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   13. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   14. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   15. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   16. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   17. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   18. [2025-10-30 03:47:33Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   19. [2025-10-30 03:47:33Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   20. [2025-10-30 03:47:33Z] PID:3856 - Process accessed (rule: ProcessAccess)
#
# ... and 222 more results not displayed

# %% [markdown]
# ---
# Bonus: NotifyRoutineAddress refers to a kernel-mode callback function address. Usually, this means a driver (often a legitimate or malicious one) has registered a function to be notified of specific events such as process creation, image loading, thread creation, registry changes, or other OS internals.
#
# The System process (PID 4), which is where kernel code sets a NotifyRoutineAddress (**0xFFFFF80487D91000**). This is the driver, NSecKrnl.sys, registering its callback function to "hook" into the operating system. This hook allows it to be notified of events, such as when a process is created.

# %%
hunter.search('NotifyRoutineAddress')
# Out:
# [*] Searching for 'NotifyRoutineAddress' across all fields...
# [+] Found 2 events containing 'NotifyRoutineAddress'
#
# Showing all 2 matches:
#
#   1. [2025-10-30 03:47:33Z] PID:4
#
#   2. [2025-10-30 03:48:20Z] PID:4
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 4,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 5204,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'NotifyRoutineAddress': '0xFFFFF80487D91000',
#    'ReturnCode': 0},
#   'property_types': {'NotifyRoutineAddress': 'POINTER',
#    'ReturnCode': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 4,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 5188,
#    'timestamp': '2025-10-30 03:48:20Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'NotifyRoutineAddress': '0xFFFFF80487DA3DD8',
#    'ReturnCode': 0},
#   'property_types': {'NotifyRoutineAddress': 'POINTER',
#    'ReturnCode': 'UINT32'}}]

# %% [markdown]
# ---
# **List providers and associated events related to nsec-killer.exe name alone?**

# %%
provider_event_pairs = set()
for event in hunter.search('nsec-killer.exe'):
    provider, event_id = event.get('header', {}).get('provider_name'), event.get('header', {}).get('event_id')
    if provider and event_id:
        provider_event_pairs.add((provider, event_id))
for pair in sorted(list(provider_event_pairs)):
    print(f"  Provider: {pair[0]:<40} Event ID: {pair[1]}")
# Out:
# [*] Searching for 'nsec-killer.exe' across all fields...
# [+] Found 29 events containing 'nsec-killer.exe'
#
# Showing first 20 matches:
#
#   1. [2025-10-30 03:47:33Z] PID:2176
#      Found in: properties.FileNameBuffer=\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   2. [2025-10-30 03:47:33Z] PID:2176
#      Found in: properties.ImageName=\Device\HarddiskVolume2\Users\cyb3r\Downloads\NSec
#
#   3. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   4. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   5. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.CommandLine=NSec-Killer.exe  -n msmpeng.exe
#      Also in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   6. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   7. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   8. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   9. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   10. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   11. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   12. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   13. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   14. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetImage=c:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   15. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   16. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   17. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   18. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   19. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
#   20. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.Image=C:\Users\cyb3r\Downloads\NSec-Killer.exe
#
# ... and 9 more results not displayed
# 💡 Tip: All 29 results are stored in your variable.
#          Use display_limit to show more: search('term', display_limit=50)
#   Provider: Microsoft-Windows-CodeIntegrity          Event ID: 3040
#   Provider: Microsoft-Windows-Kernel-File            Event ID: 10
#   Provider: Microsoft-Windows-Kernel-File            Event ID: 11
#   Provider: Microsoft-Windows-Kernel-Process         Event ID: 1
#   Provider: Microsoft-Windows-Sysmon                 Event ID: 1
#   Provider: Microsoft-Windows-Sysmon                 Event ID: 7
#   Provider: Microsoft-Windows-Sysmon                 Event ID: 10
#   Provider: Microsoft-Windows-Sysmon                 Event ID: 11

# %% [markdown]
# ----
# **What DLLs did the Nsec-Killer.exe process load?**

# %%
loaded_dlls = set()
events = hunter.search(
    provider_name="Microsoft-Windows-Sysmon",
    event_id=7,
    Image="Nsec-Killer.exe"
)

for event in events:
    dll = event.get('properties', {}).get('ImageLoaded')
    if dll:
        loaded_dlls.add(dll)

print(f"\nFound {len(loaded_dlls)} unique DLLs loaded by 'Nsec-Killer.exe':\n")
for dll in sorted(list(loaded_dlls)):
    print(dll)
# Out:
# [*] Found 12 matching events
#   1. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   2. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   3. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   4. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   5. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   6. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   7. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   8. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   9. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   10. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   11. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#   12. [2025-10-30 03:47:33Z] PID:3856 - Image loaded (rule: ImageLoad)
#
# Found 12 unique DLLs loaded by 'Nsec-Killer.exe':
#
# C:\Users\cyb3r\Downloads\NSec-Killer.exe
# C:\Windows\System32\KernelBase.dll
# C:\Windows\System32\advapi32.dll
# C:\Windows\System32\apphelp.dll
# C:\Windows\System32\bcryptprimitives.dll
# C:\Windows\System32\kernel32.dll
# C:\Windows\System32\msvcrt.dll
# C:\Windows\System32\ntdll.dll
# C:\Windows\System32\rpcrt4.dll
# C:\Windows\System32\sechost.dll
# C:\Windows\System32\ucrtbase.dll
# C:\Windows\System32\vcruntime140.dll

# %% [markdown]
# ----
# **What DLLs did the msmpeng.exe process load?**

# %%
loaded_dlls = set()
events = hunter.search(
    provider_name="Microsoft-Windows-Sysmon",
    event_id=7,
    Image="msmpeng.exe"
)

for event in events:
    dll = event.get('properties', {}).get('ImageLoaded')
    if dll:
        loaded_dlls.add(dll)

print(f"\nFound {len(loaded_dlls)} unique DLLs loaded by 'msmpeng.exe':\n")
for dll in sorted(list(loaded_dlls)):
    print(dll)

# %% [markdown]
# ---
# **Bonus: What Integrity level Nsec-Killer.exe invoked with?**

# %%
hunter.search(provider_name = 'Microsoft-Windows-Kernel-Process',task_name = 'ProcessStart', ImageName = 'Nsec')
# Out:
# [*] Found 1 matching events
#   1. [2025-10-30 03:47:33Z] PID:2176 - ProcessStart
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 2176,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 7552,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:47:33Z',
#    'Flags': 0,
#    'ImageChecksum': 0,
#    'ImageName': '\\Device\\HarddiskVolume2\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'MandatoryLabel': 'Mandatory Label\\High Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 2176,
#    'ParentProcessSequenceNumber': 179,
#    'ProcessID': 6872,
#    'ProcessSequenceNumber': 256,
#    'ProcessTokenElevationType': 2,
#    'ProcessTokenIsElevated': 1,
#    'SessionID': 1,
#    'TimeDateStamp': 1761536540},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}}]

# %% [markdown]
# ---
# **Environmental Knowledge**
#
#
# 1. Baseline which drivers are present using registry logs at \\Registry\\Machine\\System\\CurrentControlSet\\Control\\Compatibility\\Driver\\. Many EDR killers will check for if the driver/service is present or not and most definitely get (STATUS_OBJECT_NAME_NOT_FOUND).  Unfortunately, not all logs are captured in sysmon. Few that do exists need extensive baseline. apphelp.dll will be loaded by a process to check for Application Compatibility.
#
# 2. We do know (I'm hoping) which EDR we have, where adversary might not (I say might not as sometime there are targeted like cases in Sophos). We can use this to our advantage to check any queries to EDR software other than yours

# %%
"""
Unique GrantedAccess per SourceProcessId, and TargetProcessId
"""

from collections import defaultdict
access_map = defaultdict(set)
for event in hunter.search('GrantedAccess'):
    pid, target_pid = event.get('properties', {}).get('SourceProcessId'), event.get('properties', {}).get('TargetProcessId')
    access = event.get('properties', {}).get('GrantedAccess')
    if pid is not None and target_pid is not None and access is not None and pid != target_pid:
        access_map[(pid, target_pid)].add(access)
print(f"\nFound {len(access_map)} unique (SourceProcessId -> TargetProcessID) pairs (where source != target):\n")
for (pid, target_pid), accesses in sorted(access_map.items()):
    print(f"  PID: {pid:<6} -> Target PID: {target_pid:<6} -> Access Codes: {sorted(list(accesses))}")
# Out:
# [*] Searching for 'GrantedAccess' across all fields...
# [+] Found 242 events containing 'GrantedAccess'
#
# Showing first 20 matches:
#
#   1. [2025-10-30 03:47:28Z] PID:3856
#
#   2. [2025-10-30 03:47:28Z] PID:3856
#
#   3. [2025-10-30 03:47:28Z] PID:3856
#
#   4. [2025-10-30 03:47:28Z] PID:3856
#
#   5. [2025-10-30 03:47:28Z] PID:3856
#
#   6. [2025-10-30 03:47:28Z] PID:3856
#
#   7. [2025-10-30 03:47:28Z] PID:3856
#
#   8. [2025-10-30 03:47:28Z] PID:3856
#
#   9. [2025-10-30 03:47:28Z] PID:3856
#
#   10. [2025-10-30 03:47:28Z] PID:3856
#
#   11. [2025-10-30 03:47:28Z] PID:3856
#
#   12. [2025-10-30 03:47:28Z] PID:3856
#
#   13. [2025-10-30 03:47:28Z] PID:3856
#
#   14. [2025-10-30 03:47:28Z] PID:3856
#
#   15. [2025-10-30 03:47:28Z] PID:3856
#
#   16. [2025-10-30 03:47:28Z] PID:3856
#
#   17. [2025-10-30 03:47:28Z] PID:3856
#
#   18. [2025-10-30 03:47:33Z] PID:3856
#
#   19. [2025-10-30 03:47:33Z] PID:3856
#
#   20. [2025-10-30 03:47:33Z] PID:3856
#
# ... and 222 more results not displayed
# 💡 Tip: All 242 results are stored in your variable.
#          Use display_limit to show more: search('term', display_limit=50)
#
# Found 54 unique (SourceProcessId -> TargetProcessID) pairs (where source != target):
#
#   PID: 652    -> Target PID: 272    -> Access Codes: ['00100000']
#   PID: 652    -> Target PID: 756    -> Access Codes: ['00100000', 'FFFF1F00']
#   PID: 652    -> Target PID: 6872   -> Access Codes: ['00100000']
#   PID: 820    -> Target PID: 420    -> Access Codes: ['00200000']
#   PID: 820    -> Target PID: 3812   -> Access Codes: ['00100000']
#   PID: 820    -> Target PID: 6932   -> Access Codes: ['00200000']
#   PID: 820    -> Target PID: 7336   -> Access Codes: ['00200000']
#   PID: 820    -> Target PID: 7588   -> Access Codes: ['00200000']
#   PID: 820    -> Target PID: 7660   -> Access Codes: ['00100000']
#   PID: 820    -> Target PID: 7952   -> Access Codes: ['00100000']
#   PID: 912    -> Target PID: 7660   -> Access Codes: ['00001000']
#   PID: 968    -> Target PID: 704    -> Access Codes: ['00100000']
#   PID: 968    -> Target PID: 2496   -> Access Codes: ['00100000']
#   PID: 968    -> Target PID: 2648   -> Access Codes: ['00100000']
#   PID: 968    -> Target PID: 3856   -> Access Codes: ['00100000']
#   PID: 1112   -> Target PID: 3812   -> Access Codes: ['00100000']
#   PID: 1640   -> Target PID: 2488   -> Access Codes: ['00300000']
#   PID: 1640   -> Target PID: 6872   -> Access Codes: ['00300000']
#   PID: 1640   -> Target PID: 7660   -> Access Codes: ['00300000']
#   PID: 2176   -> Target PID: 6872   -> Access Codes: ['FFFF1F00']
#   PID: 2648   -> Target PID: 4      -> Access Codes: ['00101000']
#   PID: 2648   -> Target PID: 2176   -> Access Codes: ['00100000', '00101000', '00140000']
#   PID: 2648   -> Target PID: 6872   -> Access Codes: ['00100000', '00101000', '00220000', '10140000']
#   PID: 2648   -> Target PID: 7588   -> Access Codes: ['00100000', '00101000']
#   PID: 3804   -> Target PID: 4824   -> Access Codes: ['00100000']
#   PID: 3856   -> Target PID: 5532   -> Access Codes: ['FFFF1F00']
#   PID: 3856   -> Target PID: 7224   -> Access Codes: ['00100000']
#   PID: 3856   -> Target PID: 7328   -> Access Codes: ['00100000']
#   PID: 4200   -> Target PID: 420    -> Access Codes: ['00100000']
#   PID: 4200   -> Target PID: 6932   -> Access Codes: ['00100000']
#   PID: 4200   -> Target PID: 7336   -> Access Codes: ['00100000']
#   PID: 4200   -> Target PID: 7588   -> Access Codes: ['00100000']
#   PID: 4496   -> Target PID: 2176   -> Access Codes: ['00100000']
#   PID: 4496   -> Target PID: 2192   -> Access Codes: ['00200000']
#   PID: 4496   -> Target PID: 4056   -> Access Codes: ['00200000']
#   PID: 4496   -> Target PID: 5172   -> Access Codes: ['00100000']
#   PID: 4496   -> Target PID: 5576   -> Access Codes: ['00200000']
#   PID: 4496   -> Target PID: 7100   -> Access Codes: ['00200000']
#   PID: 4496   -> Target PID: 7224   -> Access Codes: ['00100000']
#   PID: 4496   -> Target PID: 7328   -> Access Codes: ['00100000']
#   PID: 4496   -> Target PID: 7796   -> Access Codes: ['00200000']
#   PID: 4496   -> Target PID: 8052   -> Access Codes: ['00200000']
#   PID: 4496   -> Target PID: 8076   -> Access Codes: ['00200000']
#   PID: 4824   -> Target PID: 2176   -> Access Codes: ['00100000']
#   PID: 4824   -> Target PID: 7224   -> Access Codes: ['00100000']
#   PID: 4824   -> Target PID: 7328   -> Access Codes: ['00100000']
#   PID: 5000   -> Target PID: 7952   -> Access Codes: ['FFFF1F00']
#   PID: 6932   -> Target PID: 272    -> Access Codes: ['FFFF1F00']
#   PID: 6932   -> Target PID: 4432   -> Access Codes: ['FFFF1F00']
#   PID: 6932   -> Target PID: 4636   -> Access Codes: ['FFFF1F00']
#   PID: 7224   -> Target PID: 272    -> Access Codes: ['FFFF1F00']
#   PID: 7224   -> Target PID: 4432   -> Access Codes: ['FFFF1F00']
#   PID: 7224   -> Target PID: 4636   -> Access Codes: ['FFFF1F00']
#   PID: 7588   -> Target PID: 6872   -> Access Codes: ['FFFF1F00']

# %% [markdown]
# ----
# **Hunt Package 1: Process + File + Registry**
#
# This package hunts the core of the attack: a suspicious process (NSec-Killer.exe) is launched, a driver file (NSecKrnl.sys) is loaded, and a registry key (ImagePath) is created to link them.
#
# Correlation:
#
# (Process) Sysmon Event 1 shows NSec-Killer.exe (PID 6872) is created.
#
# (Registry) Sysmon Event 13 shows services.exe (PID 652) creating an ImagePath for a service named NSecKrnl.
#
# (File) Sysmon Event 6 shows the kernel loading the driver NSecKrnl.sys from the exact path specified in the registry log.

# %% [markdown]
# ---
# **Package 2: Registry + Service Process + Registry + Image**
#
# High-fidelity chain, showing the complete service installation and driver load sequence.
#
# Correlation:
#
# (Registry - CreateKey): Sysmon Event 12 shows a new service key NSecKrnl being created.
#
# (Service Process): The same log identifies the actor: Image: C:\\Windows\\system32\\services.exe (PID 652).
#
# (Registry - Configure): Sysmon Event 13 shows the same process (PID 652) setting the ImagePath to NSecKrnl.sys.
#
# (Image - Load): Sysmon Event 6 shows the kernel loading the exact file from the ImagePath: ImageLoaded: ...NSecKrnl.sys.

# %% [markdown]
# ----
# **Package 3: Registry + Service (Cleanup)**
# The creation of a service registry key followed by a sc.exe (Service Control) command targeting the same service name. The delete command is deliberately not included in the log but you should see that.
#
# Correlation:
#
# (Registry): Sysmon Event 12 shows the creation of the service key HKLM\\...\\NSecKrnl.
#
# (Service): A Sysmon Event 1 log shows sc.exe being used to interact with a service named nseckrnl (the CommandLine field).

# %% [markdown]
# ---
# **Check the logic of Package 2:**
#
# A Registry Event (Sysmon 12 or 13) from the Service Process (services.exe, PID 652) creates or modifies a service's ImagePath.
#
# An Image Load Event (Sysmon 6) occurs where the ImageLoaded file path matches the ImagePath from the registry.
#
# Using this exact logic, we find another suspicious driver load in the logs but has not performed full BYOVD.
#
# **A Registry Event**
#
# We find a log where services.exe (PID 652) sets a new, suspicious ImagePath.
#
# The new service name (changed_to_exe) and the new file (Sysnom.exe).
#
# Image: C:\Windows\System32\sc.exe
#
# CommandLine: sc create changed_to_exe type = kernel binpath=C:\Users\cyb3r\Downloads\Sysnom.exe
#
#
# Image: C:\Windows\System32\sc.exe
#
# CommandLine: sc create changed_to_exe type=kernel binpath=C:\Users\cyb3r\Downloads\Sysnom.exe
#
# **The Image Load Event**
# The kernel loads the exact file specified in the ImagePath from Step 1.
#
# This is not a BYOVD attack performing to kill Defender, but rather a successful hunt of a suspicious driver load using the same pattern. The fact that an .exe file (Sysnom.exe) is being loaded as a driver proves that the driver need not be .sys, but the PE structure needs to be intact.

# %%
from collections import defaultdict

# This function creates a new, empty dictionary for our defaultdict
def new_target_entry():
    return {'count': 0, 'target_process_guids': set(), 'target_process_ids': set(), 'target_process_guid_count': defaultdict(int)}

target_data = defaultdict(new_target_entry)

# --- 1. Process the Data ---
for event in processaccess:
    props = event.get('properties', {})
    target_image, target_guid, target_pid = props.get('TargetImage'), props.get('TargetProcessGUID'), props.get('TargetProcessId')
    if not (target_image and target_guid and target_pid): continue
    stats = target_data[target_image]
    stats['count'] += 1; stats['target_process_guids'].add(target_guid); stats['target_process_ids'].add(target_pid); stats['target_process_guid_count'][target_guid] += 1

# %%
"""
Checking the Nsec-Killer.exe using the TargetProcessGUID. It shows, MsmpEng.exe is "scanning" Nsec-Killer.exe" when it is invoked by cmd.exe
with ParentProcessGuid': '{39898580-DC27-6902-B300-000000000300}' and 'properties': {'CommandLine': 'NSec-Killer.exe  -n msmpeng.exe'. 
Nsec-Killer then loads DLLs it suppose to, invokes service.exe to register the system driver
"""
hunter.search('{39898580-DFD5-6902-0001-000000000300}')
# Out:
# [*] Searching for '{39898580-DFD5-6902-0001-000000000300}' across all fields...
# [+] Found 24 events containing '{39898580-DFD5-6902-0001-000000000300}'
#
# Showing first 20 matches:
#
#   1. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   2. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   3. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   4. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   5. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   6. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   7. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   8. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   9. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   10. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   11. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   12. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
#   13. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   14. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   15. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   16. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   17. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   18. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   19. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.ProcessGuid={39898580-DFD5-6902-0001-000000000300}
#
#   20. [2025-10-30 03:47:33Z] PID:3856
#      Found in: properties.TargetProcessGUID={39898580-DFD5-6902-0001-000000000300}
#
# ... and 4 more results not displayed
# 💡 Tip: All 24 results are stored in your variable.
#          Use display_limit to show more: search('term', display_limit=50)
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+35d597|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+298796|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+29b60b|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+29c323|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+3052a6|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+30d001|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+30b996|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+1cfbeb|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+251a4b|C:\\Program Files\\Windows Defender\\mpsvc.dll+17e97|C:\\Program Files\\Windows Defender\\mprtp.dll+165c3|C:\\Program Files\\Windows Defender\\mprtp.dll+22aab|C:\\Program Files\\Windows Defender\\mprtp.dll+29b51|C:\\Program Files\\Windows Defender\\mprtp.dll+451d8|C:\\Program Files\\Windows Defender\\mprtp.dll+457ac|C:\\Program Files\\Windows Defender\\mprtp.dll+869a0|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00220000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 3672,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489480|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489254|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489598|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b38a4|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b699a|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2a35dc|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2a4c50|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+1e97e5|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+1e9225|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+750912|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+74f3dd|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+32e36f|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+30bf89|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+30b996|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+1cfbeb|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+251a4b|C:\\Program Files\\Windows Defender\\mpsvc.dll+17e97|C:\\Program Files\\Windows Defender\\mprtp.dll+1588c|C:\\Program Files\\Windows Defender\\mprtp.dll+3b971|C:\\Program Files\\Windows Defender\\mpclient.dll+81b03|C:\\Windows\\SYSTEM32\\ntdll.dll+62260|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 2968,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 5,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process Create (rule: ProcessCreate) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CommandLine': 'NSec-Killer.exe  -n msmpeng.exe',
#    'Company': '-',
#    'CurrentDirectory': 'c:\\Users\\cyb3r\\Downloads\\',
#    'Description': '-',
#    'FileVersion': '-',
#    'Hashes': 'SHA1=736230F44614A33720C3D60E35B2E314DE0C9E8C,MD5=858505745A6AB5D5C3516FC007895476,SHA256=889A707D9DE8662C8C4A077F6FF1877A0189BB9AF802627CB646EC561739AB44,IMPHASH=94F110D17AC8BB0A70880C3C6B3182EE',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'IntegrityLevel': 'High',
#    'LogonGuid': '{39898580-DB88-6902-2284-030000000000}',
#    'LogonId': '2284030000000000',
#    'OriginalFileName': '-',
#    'ParentCommandLine': '"C:\\Windows\\system32\\cmd.exe" ',
#    'ParentImage': 'C:\\Windows\\System32\\cmd.exe',
#    'ParentProcessGuid': '{39898580-DC27-6902-B300-000000000300}',
#    'ParentProcessId': 2176,
#    'ParentUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': '-',
#    'RuleName': '-',
#    'TerminalSessionId': 1,
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'CommandLine': 'STRINGW',
#    'Company': 'STRINGW',
#    'CurrentDirectory': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'IntegrityLevel': 'STRINGW',
#    'LogonGuid': 'GUID',
#    'LogonId': 'OTHER',
#    'OriginalFileName': 'STRINGW',
#    'ParentCommandLine': 'STRINGW',
#    'ParentImage': 'STRINGW',
#    'ParentProcessGuid': 'GUID',
#    'ParentProcessId': 'UINT32',
#    'ParentUser': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'TerminalSessionId': 'UINT32',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9e974|C:\\Windows\\System32\\KERNELBASE.dll+5b3d3|C:\\Windows\\System32\\KERNELBASE.dll+59746|C:\\Windows\\System32\\KERNEL32.DLL+1d334|C:\\Windows\\system32\\cmd.exe+14486|C:\\Windows\\system32\\cmd.exe+15b7f|C:\\Windows\\system32\\cmd.exe+c9bd|C:\\Windows\\system32\\cmd.exe+bea1|C:\\Windows\\system32\\cmd.exe+1ebf0|C:\\Windows\\system32\\cmd.exe+18ecd|C:\\Windows\\System32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': 'FFFF1F00',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\cmd.exe',
#    'SourceProcessGUID': '{39898580-DC27-6902-B300-000000000300}',
#    'SourceProcessId': 2176,
#    'SourceThreadId': 7552,
#    'SourceUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'NT Layer DLL',
#    'FileVersion': '10.0.19041.2788 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=959735A57905CB6037AF73CB29A4CF99FB5F95FE,MD5=821267661AB8AD7C9AD1D3D44DEBAB08,SHA256=FDB2689BFFABE7D2E300882CA1C3FC2FE24A998FFCBD5F48795C7D95712D1E98,IMPHASH=00000000000000000000000000000000',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\ntdll.dll',
#    'OriginalFileName': 'ntdll.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.719'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Windows NT BASE API Client DLL',
#    'FileVersion': '10.0.19041.2913 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=FB493CD7E14273DE7EA0A2963CCA1AF538A36E04,MD5=CFDF6EC893DB3D8C517AFA314ED35929,SHA256=CCC676070124C2018231472123F12ACC7A12C74314970C2DADDEB33A6A6A5E2D,IMPHASH=A19C3670940B41B2635DBEE7B53D2D43',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\kernel32.dll',
#    'OriginalFileName': 'kernel32',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Windows NT BASE API Client DLL',
#    'FileVersion': '10.0.19041.2913 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=17265C10D077E8B82803F6ABF6C2BB9885728686,MD5=B59372DB9EA5DCE4C4961CF4AA9AD3EF,SHA256=AD1AF6083D13D8BCD87408066093A41624F9389C8034F22E93D1CDEAA5FA352E,IMPHASH=DEAAE2D8BB9E25EB885935B351970716',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\KernelBase.dll',
#    'OriginalFileName': 'Kernelbase.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\System32\\KERNELBASE.dll+308ee|C:\\Windows\\system32\\conhost.exe+13909|C:\\Windows\\system32\\conhost.exe+13a51|C:\\Windows\\system32\\conhost.exe+13bac|C:\\Windows\\system32\\conhost.exe+106cc|C:\\Windows\\System32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': 'FFFF1F00',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\conhost.exe',
#    'SourceProcessGUID': '{39898580-DC27-6902-B400-000000000300}',
#    'SourceProcessId': 7588,
#    'SourceThreadId': 536,
#    'SourceUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489480|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489254|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489598|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b7152|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b682f|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e6883|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+362f02|C:\\Windows\\SYSTEM32\\ntdll.dll+62260|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 2968,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489480|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489254|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489598|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b71e5|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b682f|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e6883|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+362f02|C:\\Windows\\SYSTEM32\\ntdll.dll+62260|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 2968,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489480|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489254|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b57a7|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b6c38|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e1cb3|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2c9cba|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2eb335|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b8991|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b65c3|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b7212|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b682f|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e6883|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+362f02|C:\\Windows\\SYSTEM32\\ntdll.dll+62260|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '10140000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 2968,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489480|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489254|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+48aa2b|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+58f65d|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+5c80f6|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+5c399b|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+5c37a4|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+5c3711|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b8add|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b65c3|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b7212|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b682f|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e6883|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+362f02|C:\\Windows\\SYSTEM32\\ntdll.dll+62260|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00101000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 2968,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.734'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Application Compatibility Client Library',
#    'FileVersion': '10.0.19041.2913 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=F581DCF3C8032626D2A945DA06FDE6B4284E6D2F,MD5=96EB50382450A941188D8684B87597BB,SHA256=85EC4FD50FF51B2D98E411E2D2907A5209DBD924F418CC352D322AB574030D99,IMPHASH=25498F33E8A63D2D29D6A31AB8B6ABD3',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\apphelp.dll',
#    'OriginalFileName': 'Apphelp',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Windows Cryptographic Primitives Library',
#    'FileVersion': '10.0.19041.2486 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=3D582D85D9FAE1CD3579701BB6A49C6E0EFC5C0C,MD5=33F88521EB7778D5993779C5BB8E430C,SHA256=7808F3DD0B2C0B6B909363720E630E7A1EA4B58A0E5467242B8E86EFA5C91C72,IMPHASH=496E42068C9391511CF6EE7C54F73A9B',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\bcryptprimitives.dll',
#    'OriginalFileName': 'bcryptprimitives.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Advanced Windows 32 Base API',
#    'FileVersion': '10.0.19041.2913 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=AEC71933DB066744EFF7B63BFCC4FB89E36D1765,MD5=A74AF6C8A893F21284A870DD15DA5880,SHA256=6F6C7E0C5944B3AA43EFFD1D4AD95D1C7B8818A1924AC04043EDD9F29E34B85C,IMPHASH=35492F96EA2A10913DE3168F53731A6A',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\advapi32.dll',
#    'OriginalFileName': 'advapi32.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Windows NT CRT DLL',
#    'FileVersion': '7.0.19041.546 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=5AFF4CFDEE689F127DF3C555281DC629D4D62318,MD5=A4F2D5942FB447CD48A5CEE414983E85,SHA256=DD7C8BC34CDBE30EF921395E874909BBF6BE53803822164F75F7207E9F085650,IMPHASH=1273683626EBBA703979F188A1E64237',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\msvcrt.dll',
#    'OriginalFileName': 'msvcrt.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Host for SCM/SDDL/LSA Lookup APIs',
#    'FileVersion': '10.0.19041.2913 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=BBC78B7C6DD3937B2540C7C7001287A5FD937574,MD5=D5F94513E1731C22BC8854430EAA56C2,SHA256=2427BE8FE5683710405618E006AF770FEBA6E8EF20AD443B7AF7E8C1C72B63D9,IMPHASH=CE4BD072766253F6A267D0284CA82002',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\sechost.dll',
#    'OriginalFileName': 'sechost.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Remote Procedure Call Runtime',
#    'FileVersion': '10.0.19041.2965 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=704830DE2890526D8212EC65FFF3D3BDF22A08B3,MD5=F90EA560D65015A1DAF74CB6867F985F,SHA256=170452C597CFAF5CE91F5559E6C59565C8DA1F7950B84A6EA5CE6CDAB34AACC1,IMPHASH=691FED08D927C769FAAC5041B85477B5',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\rpcrt4.dll',
#    'OriginalFileName': 'rpcrt4.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Microsoft C Runtime Library',
#    'FileVersion': '10.0.19041.789 (WinBuild.160101.0800)',
#    'Hashes': 'SHA1=E82945E3E63FFEF0974D6DD74F2AEF2BF6D0A908,MD5=2C8FE06966D5085A595FFA3C98FE3098,SHA256=DE8D08D01291DF93821314176381F3D1AE863E6C5584A7F8EA42F0B94B15EF65,IMPHASH=405CDE0FC80C30DCC3D783173DBD4143',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\ucrtbase.dll',
#    'OriginalFileName': 'ucrtbase.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Windows Operating System',
#    'RuleName': '-',
#    'Signature': 'Microsoft Windows',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.750'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489480|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+489254|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b57a7|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b6c38|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e20f5|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2c9cba|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2eb335|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b8991|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b65c3|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2b684a|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+2e6883|C:\\ProgramData\\Microsoft\\Windows Defender\\Definition Updates\\Default\\mpengine.dll+362f02|C:\\Windows\\SYSTEM32\\ntdll.dll+62260|C:\\Windows\\SYSTEM32\\ntdll.dll+531aa|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '10140000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'SourceProcessGUID': '{39898580-DB72-6902-3F00-000000000300}',
#    'SourceProcessId': 2648,
#    'SourceThreadId': 3724,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.765'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 7964,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': '-',
#    'Description': '-',
#    'FileVersion': '-',
#    'Hashes': 'SHA1=736230F44614A33720C3D60E35B2E314DE0C9E8C,MD5=858505745A6AB5D5C3516FC007895476,SHA256=889A707D9DE8662C8C4A077F6FF1877A0189BB9AF802627CB646EC561739AB44,IMPHASH=94F110D17AC8BB0A70880C3C6B3182EE',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'OriginalFileName': '-',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': '-',
#    'RuleName': '-',
#    'Signature': '-',
#    'SignatureStatus': 'Unavailable',
#    'Signed': 'false',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.719'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\SYSTEM32\\KERNELBASE.dll+308ee|C:\\Windows\\system32\\services.exe+3643f|C:\\Windows\\system32\\services.exe+25774|C:\\Windows\\system32\\services.exe+254df|C:\\Windows\\system32\\services.exe+5a03a|C:\\Windows\\system32\\services.exe+5a851|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7b253|C:\\Windows\\SYSTEM32\\RPCRT4.dll+7a022|C:\\Windows\\SYSTEM32\\RPCRT4.dll+1e09a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+5dd7a|C:\\Windows\\SYSTEM32\\RPCRT4.dll+58f88|C:\\Windows\\SYSTEM32\\RPCRT4.dll+3a1a6|C:\\Windows\\SYSTEM32\\RPCRT4.dll+39af8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+472bf|C:\\Windows\\SYSTEM32\\RPCRT4.dll+466c8|C:\\Windows\\SYSTEM32\\RPCRT4.dll+45cb1|C:\\Windows\\SYSTEM32\\RPCRT4.dll+4571e|C:\\Windows\\SYSTEM32\\RPCRT4.dll+49e32|C:\\Windows\\SYSTEM32\\ntdll.dll+20330|C:\\Windows\\SYSTEM32\\ntdll.dll+52f76|C:\\Windows\\SYSTEM32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00100000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\services.exe',
#    'SourceProcessGUID': '{39898580-DB6A-6902-0B00-000000000300}',
#    'SourceProcessId': 652,
#    'SourceThreadId': 7896,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.781'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 7,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Image loaded (rule: ImageLoad) ',
#    'thread_id': 7964,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Company': 'Microsoft Corporation',
#    'Description': 'Microsoft C Runtime Library',
#    'FileVersion': '14.32.31326.0',
#    'Hashes': 'SHA1=77771D8419FC20F5E351F8C612694DD8FBBA974C,MD5=A3FAD57D5A6E0A0D0A0F2378888F1415,SHA256=80F06C0740F31019F76FB1398A1112B3E02D1B80AEE7D3A738D475408D7B4C60,IMPHASH=7F07FD94E5BB907093556781CC464017',
#    'Image': 'C:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'ImageLoaded': 'C:\\Windows\\System32\\vcruntime140.dll',
#    'OriginalFileName': 'vcruntime140.dll',
#    'ProcessGuid': '{39898580-DFD5-6902-0001-000000000300}',
#    'ProcessId': 6872,
#    'Product': 'Microsoft Visual Studio',
#    'RuleName': '-',
#    'Signature': 'Microsoft Corporation',
#    'SignatureStatus': 'Valid',
#    'Signed': 'true',
#    'User': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:33.765'},
#   'property_types': {'Company': 'STRINGW',
#    'Description': 'STRINGW',
#    'FileVersion': 'STRINGW',
#    'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ImageLoaded': 'STRINGW',
#    'OriginalFileName': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'Product': 'STRINGW',
#    'RuleName': 'STRINGW',
#    'Signature': 'STRINGW',
#    'SignatureStatus': 'STRINGW',
#    'Signed': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 10,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process accessed (rule: ProcessAccess) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:37Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CallTrace': 'C:\\Windows\\SYSTEM32\\ntdll.dll+9d524|C:\\Windows\\System32\\KERNELBASE.dll+308ee|c:\\windows\\system32\\sysmain.dll+4737d|c:\\windows\\system32\\sysmain.dll+471fc|c:\\windows\\system32\\sysmain.dll+2a6d4|c:\\windows\\system32\\sysmain.dll+2a331|c:\\windows\\system32\\sysmain.dll+66cf1|c:\\windows\\system32\\sysmain.dll+7b59e|c:\\windows\\system32\\sysmain.dll+67ecf|C:\\Windows\\system32\\svchost.exe+4340|C:\\Windows\\System32\\sechost.dll+dfd8|C:\\Windows\\System32\\KERNEL32.DLL+17614|C:\\Windows\\SYSTEM32\\ntdll.dll+526a1',
#    'GrantedAccess': '00300000',
#    'RuleName': '-',
#    'SourceImage': 'C:\\Windows\\system32\\svchost.exe',
#    'SourceProcessGUID': '{39898580-DB71-6902-2500-000000000300}',
#    'SourceProcessId': 1640,
#    'SourceThreadId': 1716,
#    'SourceUser': 'NT AUTHORITY\\SYSTEM',
#    'TargetImage': 'c:\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'TargetProcessGUID': '{39898580-DFD5-6902-0001-000000000300}',
#    'TargetProcessId': 6872,
#    'TargetUser': 'DESKTOP-3AERCN7\\cyb3r',
#    'UtcTime': '2025-10-30 03:47:37.755'},
#   'property_types': {'CallTrace': 'STRINGW',
#    'GrantedAccess': 'OTHER',
#    'RuleName': 'STRINGW',
#    'SourceImage': 'STRINGW',
#    'SourceProcessGUID': 'GUID',
#    'SourceProcessId': 'UINT32',
#    'SourceThreadId': 'UINT32',
#    'SourceUser': 'STRINGW',
#    'TargetImage': 'STRINGW',
#    'TargetProcessGUID': 'GUID',
#    'TargetProcessId': 'UINT32',
#    'TargetUser': 'STRINGW',
#    'UtcTime': 'STRINGW'}}]

# %%
hunter.search(TargetProcessId = 2648)
# Out:
# [*] Found 9 matching events
#   1. [2025-10-30 03:47:33Z] PID:2648 -
#   2. [2025-10-30 03:47:33Z] PID:2648 -
#   3. [2025-10-30 03:47:33Z] PID:2648 -
#   4. [2025-10-30 03:47:33Z] PID:2648 -
#   5. [2025-10-30 03:47:33Z] PID:2648 -
#   6. [2025-10-30 03:47:33Z] PID:2648 -
#   7. [2025-10-30 03:47:34Z] PID:2648 -
#   8. [2025-10-30 03:47:34Z] PID:2648 -
#   9. [2025-10-30 03:47:34Z] PID:2648 -
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 5600,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 5600,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 5600,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 5600,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 6336,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 6336,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 3688,
#    'timestamp': '2025-10-30 03:47:34Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 3688,
#    'timestamp': '2025-10-30 03:47:34Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 2648,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 3688,
#    'timestamp': '2025-10-30 03:47:34Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'DesiredAccess': 2147483648,
#    'ReturnCode': 0,
#    'TargetProcessId': 2648},
#   'property_types': {'DesiredAccess': 'UINT32',
#    'ReturnCode': 'UINT32',
#    'TargetProcessId': 'UINT32'}}]

# %%
import json
VICTIM_PID, ATTACKER_PID_STR = 2648, "6872"
print(f"--- Part 1: Searching for all events targeting PID {VICTIM_PID} ---")
victim_access_events = hunter.search(TargetProcessId=VICTIM_PID, display_limit=None)
print(f"\n--- Part 2: Correlating logs for attacker PID '{ATTACKER_PID_STR}' ---")
correlating_logs = [log for log in victim_access_events if ATTACKER_PID_STR in json.dumps(log).lower()]
for log in correlating_logs: hunter.show(log)
# Out:
# --- Part 1: Searching for all events targeting PID 2648 ---
#
# [*] Found 128 matching events
# [*] Showing first 20 of 128 results
#   1. [2025-10-30 03:47:33Z] PID:2648 -
#   2. [2025-10-30 03:47:33Z] PID:2648 -
#   3. [2025-10-30 03:47:33Z] PID:2648 -
#   4. [2025-10-30 03:47:33Z] PID:2648 -
#   5. [2025-10-30 03:47:33Z] PID:2648 -
#   6. [2025-10-30 03:47:33Z] PID:704 -
#   7. [2025-10-30 03:47:33Z] PID:704 -
#   8. [2025-10-30 03:47:33Z] PID:704 -
#   9. [2025-10-30 03:47:33Z] PID:704 -
#   10. [2025-10-30 03:47:33Z] PID:968 -
#   11. [2025-10-30 03:47:33Z] PID:968 -
#   12. [2025-10-30 03:47:33Z] PID:968 -
#   13. [2025-10-30 03:47:33Z] PID:968 -
#   14. [2025-10-30 03:47:33Z] PID:2648 -
#   15. [2025-10-30 03:47:33Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   16. [2025-10-30 03:47:33Z] PID:2648 -
#   17. [2025-10-30 03:47:33Z] PID:2648 -
#   18. [2025-10-30 03:47:33Z] PID:2648 -
#   19. [2025-10-30 03:47:33Z] PID:2648 -
#   20. [2025-10-30 03:47:33Z] PID:704 -
#
# ... and 108 more results not displayed
#
# --- Part 2: Correlating logs for attacker PID '6872' ---
#
# ================================================================================
# EVENT DETAILS
# ================================================================================
# Timestamp:    2025-10-30 03:47:33Z
# Provider:     Microsoft-Windows-Kernel-Audit-API-Calls
# Task:
# Event ID:     2 | Opcode: 0
# Process ID:   6872 | Thread ID: 2856
#
# Properties:
#   ReturnCode                : 0
#   TargetProcessId           : 2648
# ================================================================================

# %%
"""
NSec-Killer sending an API call to MsmpENG.exe. we will not know what API call is it though
"""
hunter.search(process_id = 6872,TargetProcessId = 2648)
# Out:
# [*] Found 1 matching events
#   1. [2025-10-30 03:47:33Z] PID:6872 -
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 2,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 0,
#    'process_id': 6872,
#    'provider_name': 'Microsoft-Windows-Kernel-Audit-API-Calls',
#    'task_name': '',
#    'thread_id': 2856,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'AuditAPITrace01'},
#   'properties': {'ReturnCode': 0, 'TargetProcessId': 2648},
#   'property_types': {'ReturnCode': 'UINT32', 'TargetProcessId': 'UINT32'}}]

# %%
"""
we can check the processid is indeed a Msmpeng.exe along with its process terminate event
"""
hunter.search(ProcessId =  '2648')
# Out:
# [*] Found 11 matching events
#   1. [2025-10-30 03:47:33Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   2. [2025-10-30 03:47:33Z] PID:3856 - Registry value set (rule: RegistryEvent)
#   3. [2025-10-30 03:47:33Z] PID:3856 - Registry value set (rule: RegistryEvent)
#   4. [2025-10-30 03:47:33Z] PID:3856 - File Delete logged (rule: FileDeleteDetected)
#   5. [2025-10-30 03:47:33Z] PID:3856 - File created (rule: FileCreate)
#   6. [2025-10-30 03:47:33Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   7. [2025-10-30 03:47:33Z] PID:3856 - File created (rule: FileCreate)
#   8. [2025-10-30 03:47:33Z] PID:3856 - File created (rule: FileCreate)
#   9. [2025-10-30 03:47:33Z] PID:3856 - RawAccessRead detected (rule: RawAccessRead)
#   10. [2025-10-30 03:47:33Z] PID:3856 - File Block Executable (rule: FileBlockExecutable)
#   11. [2025-10-30 03:47:34Z] PID:3856 - Process terminated (rule: ProcessTerminate)
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 12,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry object added or deleted (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'EventType': 'CreateKey',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Control\\Hvsi',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.672'},
#   'property_types': {'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 13,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry value set (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Details': '(Empty)',
#    'EventType': 'SetValue',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\SOFTWARE\\Microsoft\\Windows Defender\\Reporting\\SigUpdateTimestampsSinceLastHB',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.672'},
#   'property_types': {'Details': 'STRINGW',
#    'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 13,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry value set (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Details': 'Binary Data',
#    'EventType': 'SetValue',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\SOFTWARE\\Microsoft\\Windows Defender\\Spynet\\LastMAPSFailureTime',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.672'},
#   'property_types': {'Details': 'STRINGW',
#    'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 26,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 5,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'File Delete logged (rule: FileDeleteDetected) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Hashes': 'SHA1=D97E470F4F48EF4B61812C5E44DABA0505A6FBAB,MD5=9BE941E86EB2E397A95E4DC03A176FCF,SHA256=330F99054AE19B3E9FB77240AAF97B508CE8B65DCD41266756654DC776FF8E4A,IMPHASH=00000000000000000000000000000000',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'IsExecutable': False,
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetFilename': 'C:\\ProgramData\\Microsoft\\Windows Defender\\Scans\\History\\Store\\7F30C44116CC558404D6BC56EAD3F776',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.672'},
#   'property_types': {'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'IsExecutable': 'BOOLEAN',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetFilename': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 11,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'File created (rule: FileCreate) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CreationUtcTime': '2025-10-29 18:34:44.095',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetFilename': 'C:\\ProgramData\\Microsoft\\Windows Defender\\Scans\\History\\Store\\7F30C44116CC558404D6BC56EAD3F776',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.672'},
#   'property_types': {'CreationUtcTime': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetFilename': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 12,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry object added or deleted (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'EventType': 'CreateKey',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\SOFTWARE\\Microsoft\\Windows NT\\CurrentVersion\\ProfileList',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 11,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'File created (rule: FileCreate) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CreationUtcTime': '2025-10-30 03:47:33.687',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetFilename': 'C:\\ProgramData\\Microsoft\\Windows Defender\\Scans\\FailTelemetry',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'CreationUtcTime': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetFilename': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 11,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'File created (rule: FileCreate) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'CreationUtcTime': '2025-10-30 03:47:33.687',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetFilename': 'C:\\ProgramData\\Microsoft\\Windows Defender\\Scans\\FailTelemetry\\9AB086B3F624634380A8143F9AC02B3D',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.687'},
#   'property_types': {'CreationUtcTime': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetFilename': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 9,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'RawAccessRead detected (rule: RawAccessRead) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Device': '\\Device\\HarddiskVolume2',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.781'},
#   'property_types': {'Device': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 27,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 5,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'File Block Executable (rule: FileBlockExecutable) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Hashes': 'SHA1=2D79A17A7F226B4A3BC25D47D73570F9A33AAC1A,MD5=14B88FF4833012512278A5F3A5712BD2,SHA256=E6FE9A94E8686E957DBCEC2B89C1C1DDCF8E75D76E9200D0CBEF74D510C71317,IMPHASH=D1098E3A37F227B6FF6BD36C1801EDFA',
#    'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'TargetFilename': 'C:\\Windows\\System32\\services.exe',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.859'},
#   'property_types': {'Hashes': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetFilename': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 5,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 3,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Process terminated (rule: ProcessTerminate) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:34Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'Image': 'C:\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'ProcessGuid': '{39898580-DB72-6902-3F00-000000000300}',
#    'ProcessId': 2648,
#    'RuleName': '-',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:34.047'},
#   'property_types': {'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}}]

# %%
hunter.search(provider_name =  'Microsoft-Windows-Sysmon',event_id = 12,EventType = 'CreateKey',ProcessGuid = '{39898580-DB6A-6902-0B00-000000000300}')
# Out:
# [*] Found 2 matching events
#   1. [2025-10-30 03:47:33Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   2. [2025-10-30 03:48:09Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 12,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry object added or deleted (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'EventType': 'CreateKey',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    'ProcessGuid': '{39898580-DB6A-6902-0B00-000000000300}',
#    'ProcessId': 652,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\NSecKrnl',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:47:33.765'},
#   'property_types': {'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 12,
#    'event_name': '',
#    'event_opcode': 0,
#    'event_version': 2,
#    'process_id': 3856,
#    'provider_name': 'Microsoft-Windows-Sysmon',
#    'task_name': 'Registry object added or deleted (rule: RegistryEvent) ',
#    'thread_id': 5992,
#    'timestamp': '2025-10-30 03:48:09Z',
#    'trace_name': 'codeintegrity'},
#   'properties': {'EventType': 'CreateKey',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    'ProcessGuid': '{39898580-DB6A-6902-0B00-000000000300}',
#    'ProcessId': 652,
#    'RuleName': '-',
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\changed_to_exe',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    'UtcTime': '2025-10-30 03:48:09.827'},
#   'property_types': {'EventType': 'STRINGW',
#    'Image': 'STRINGW',
#    'ProcessGuid': 'GUID',
#    'ProcessId': 'UINT32',
#    'RuleName': 'STRINGW',
#    'TargetObject': 'STRINGW',
#    'User': 'STRINGW',
#    'UtcTime': 'STRINGW'}}]

# %%
hunter.search(provider_name = 'Microsoft-Windows-Kernel-Process',task_name = 'ProcessStart')
# Out:
# [*] Found 6 matching events
#   1. [2025-10-30 03:47:33Z] PID:2176 - ProcessStart
#   2. [2025-10-30 03:47:38Z] PID:7224 - ProcessStart
#   3. [2025-10-30 03:48:09Z] PID:7224 - ProcessStart
#   4. [2025-10-30 03:48:19Z] PID:7224 - ProcessStart
#   5. [2025-10-30 03:48:34Z] PID:652 - ProcessStart
#   6. [2025-10-30 03:49:07Z] PID:5000 - ProcessStart
# [{'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 2176,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 7552,
#    'timestamp': '2025-10-30 03:47:33Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:47:33Z',
#    'Flags': 0,
#    'ImageChecksum': 0,
#    'ImageName': '\\Device\\HarddiskVolume2\\Users\\cyb3r\\Downloads\\NSec-Killer.exe',
#    'MandatoryLabel': 'Mandatory Label\\High Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 2176,
#    'ParentProcessSequenceNumber': 179,
#    'ProcessID': 6872,
#    'ProcessSequenceNumber': 256,
#    'ProcessTokenElevationType': 2,
#    'ProcessTokenIsElevated': 1,
#    'SessionID': 1,
#    'TimeDateStamp': 1761536540},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 7224,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 3004,
#    'timestamp': '2025-10-30 03:47:38Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:47:38Z',
#    'Flags': 0,
#    'ImageChecksum': 100281,
#    'ImageName': '\\Device\\HarddiskVolume2\\Windows\\System32\\sc.exe',
#    'MandatoryLabel': 'Mandatory Label\\High Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 7224,
#    'ParentProcessSequenceNumber': 184,
#    'ProcessID': 4432,
#    'ProcessSequenceNumber': 257,
#    'ProcessTokenElevationType': 2,
#    'ProcessTokenIsElevated': 1,
#    'SessionID': 1,
#    'TimeDateStamp': 2968461829},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 7224,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 3004,
#    'timestamp': '2025-10-30 03:48:09Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:48:09Z',
#    'Flags': 0,
#    'ImageChecksum': 100281,
#    'ImageName': '\\Device\\HarddiskVolume2\\Windows\\System32\\sc.exe',
#    'MandatoryLabel': 'Mandatory Label\\High Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 7224,
#    'ParentProcessSequenceNumber': 184,
#    'ProcessID': 272,
#    'ProcessSequenceNumber': 258,
#    'ProcessTokenElevationType': 2,
#    'ProcessTokenIsElevated': 1,
#    'SessionID': 1,
#    'TimeDateStamp': 2968461829},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 7224,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 3004,
#    'timestamp': '2025-10-30 03:48:19Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:48:19Z',
#    'Flags': 0,
#    'ImageChecksum': 100281,
#    'ImageName': '\\Device\\HarddiskVolume2\\Windows\\System32\\sc.exe',
#    'MandatoryLabel': 'Mandatory Label\\High Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 7224,
#    'ParentProcessSequenceNumber': 184,
#    'ProcessID': 4636,
#    'ProcessSequenceNumber': 259,
#    'ProcessTokenElevationType': 2,
#    'ProcessTokenIsElevated': 1,
#    'SessionID': 1,
#    'TimeDateStamp': 2968461829},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 652,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 7896,
#    'timestamp': '2025-10-30 03:48:34Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:48:34Z',
#    'Flags': 0,
#    'ImageChecksum': 160529,
#    'ImageName': '\\Device\\HarddiskVolume2\\Program Files\\Windows Defender\\MsMpEng.exe',
#    'MandatoryLabel': 'Mandatory Label\\System Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 652,
#    'ParentProcessSequenceNumber': 11,
#    'ProcessID': 756,
#    'ProcessSequenceNumber': 260,
#    'ProcessTokenElevationType': 1,
#    'ProcessTokenIsElevated': 1,
#    'SessionID': 0,
#    'TimeDateStamp': 727376053},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}},
#  {'header': {'activity_id': '{00000000-0000-0000-0000-000000000000}',
#    'event_flags': 576,
#    'event_id': 1,
#    'event_name': '',
#    'event_opcode': 1,
#    'event_version': 3,
#    'process_id': 5000,
#    'provider_name': 'Microsoft-Windows-Kernel-Process',
#    'task_name': 'ProcessStart',
#    'thread_id': 5092,
#    'timestamp': '2025-10-30 03:49:07Z',
#    'trace_name': 'ProcTrace01'},
#   'properties': {'CreateTime': '2025-10-30 03:49:07Z',
#    'Flags': 0,
#    'ImageChecksum': 292033,
#    'ImageName': '\\Device\\HarddiskVolume2\\Windows\\System32\\SearchFilterHost.exe',
#    'MandatoryLabel': 'Mandatory Label\\Medium Mandatory Level',
#    'PackageFullName': '',
#    'PackageRelativeAppId': '',
#    'ParentProcessID': 5000,
#    'ParentProcessSequenceNumber': 101,
#    'ProcessID': 7952,
#    'ProcessSequenceNumber': 261,
#    'ProcessTokenElevationType': 1,
#    'ProcessTokenIsElevated': 0,
#    'SessionID': 0,
#    'TimeDateStamp': 3925705354},
#   'property_types': {'CreateTime': 'FILETIME',
#    'Flags': 'UINT32',
#    'ImageChecksum': 'UINT32',
#    'ImageName': 'STRINGW',
#    'MandatoryLabel': 'SID',
#    'PackageFullName': 'STRINGW',
#    'PackageRelativeAppId': 'STRINGW',
#    'ParentProcessID': 'UINT32',
#    'ParentProcessSequenceNumber': 'UINT64',
#    'ProcessID': 'UINT32',
#    'ProcessSequenceNumber': 'UINT64',
#    'ProcessTokenElevationType': 'UINT32',
#    'ProcessTokenIsElevated': 'UINT32',
#    'SessionID': 'UINT32',
#    'TimeDateStamp': 'UINT32'}}]

# %% [markdown]
# ---
# # Multiple events for NsecKrnl that you can use in your investigation

# %% [raw]
# 1. File Write (Event 11 - Kernel-File) → Zone.Identifier ADS creation
# 2. Code Integrity Checks (3009, 3015, 3038 - CI) → Signature validation pipeline
# 3. Registry Service Creation (12, 13 - Sysmon) → Persistence mechanism
# 4. Symbolic Link Creation (3 - Kernel-Audit-API-Calls) → Driver namespace registration
# 5. Driver Load (6 - Sysmon) → Kernel code execution
#
#
# 'event_id': 12, - 'Microsoft-Windows-Sysmon'
# 	'task_name': 'Registry object added or deleted (rule: RegistryEvent) '
# 	'properties': {'EventType': 'CreateKey',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    ProcessGuid (Useful to search for parent child by looking at ProcessGuid and src and target ProcessGuid) - to form parent child relationship
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\NSecKrnl',
#    'User': 'NT AUTHORITY\\SYSTEM',
#    ProcessId (Useful to find information on the chain but is not constant and is ephermal. Guid is the best way and this can be for context)
# 'event_id': 13,- 'Microsoft-Windows-Sysmon'
# 	'task_name': 'Registry value set (rule: RegistryEvent) ',
# 	'properties': {'Details': 'DWORD (0x00000001)', (there will another event with 'properties': {'Details': 'DWORD (0x00000002)', which suggests its a file driver but kernel driver is also file driver)
#    'EventType': 'SetValue',
#    'Image': 'C:\\Windows\\system32\\services.exe',
#    ProcessGuid (common among sysmon logs)
#    process_id
#    'TargetObject': 'HKLM\\System\\CurrentControlSet\\Services\\NSecKrnl', (there will others ending with ErrorControl, Start, Type, ImagePath,DisplayName)
#
# 'event_id': 3040,- 'Microsoft-Windows-CodeIntegrity'
# 	same as below
# 	'task_name': 'NameDelete'
# 'event_id': 10, - 'Microsoft-Windows-Kernel-File'
# 	'task_name': 'NameCreate'
# FileName': '\\Device\\HarddiskVolume2\\Users\\cyb3r\\Downloads\\NSecKrnl.sys:Zone.Identifier'}, (in properties fields)
# 'event_id': 11, - 'Microsoft-Windows-Kernel-File'
# 'event_id': 3038,- 'Microsoft-Windows-CodeIntegrity'
# 	Same same as below
# 'event_id': 3015, - 'Microsoft-Windows-CodeIntegrity'
# 	Same same as below
# 'event_id': 3009, - 'Microsoft-Windows-CodeIntegrity'
# 	'header': {'activity_id': '{3A71319B-494D-0001-1F4E-713A4D49DC01}' - connects all events related to this process across Microsoft-Windows-CodeIntegrity and have different checks (you can track those checks based on task_name)
# 	process_id (will be likely always system process)
# 	'properties': {'FileNameBuffer': '\\Device\\HarddiskVolume2\\Users\\cyb3r\\Downloads\\NSecKrnl.sys',
# 	'FileNameLength': 58
# 'event_id': 3, - 'Microsoft-Windows-Kernel-Audit-API-Calls'
#
# 	'properties': {'DesiredAccess': 983041,
# 	'process_id': 4, (will be always system process)
# 	'LinkSourceName': '\\DosDevices\\NSecKrnl',
#     'LinkTargetName': '\\Device\\NSecKrnl',
# 'event_id': 6, - 'Microsoft-Windows-Sysmon'
# 	'task_name': 'Driver loaded (rule: DriverLoad) '
# 	'Signature': 'Shandong Anzai Information Technology CO.,Ltd.'
# 	'ImageLoaded': 'C:\\Users\\cyb3r\\Downloads\\NSecKrnl.sys'
# 	'SignatureStatus': 'Valid'
# 	'Signed': 'true'
# 	process_id ( will be process that is executing nseckrnl)
# 	thread_id

# %%
hunter.search(provider_name = 'Microsoft-Windows-Kernel-Process',task_name = 'ProcessStart', ImageName = 'Nsec')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 hunter.search(provider_name = 'Microsoft-Windows-Kernel-Process',task_name = 'ProcessStart', ImageName = 'Nsec')
#
# NameError: name 'hunter' is not defined

# %% [markdown]
# ---
# # Process Tree

# %%
from collections import defaultdict

print("="*70)
print("Process VIEW")
print("="*70)

# Collect ALL Sysmon events and group by ProcessGuid
process_data = defaultdict(lambda: {
    'events': [],
    'pid': None,
    'parent_guid': None,
    'parent_pid': None,
    'image': None,
    'cmdline': None,
    'user': None,
    'integrity': None,
    'timestamps': [],
    'terminated': False,
    'exit_code': None,
    'children': []
})

# Gather all Sysmon events
for event in hunter.search(provider_name='Microsoft-Windows-Sysmon'):
    props = event.get('properties', {})
    header = event.get('header', {})
    
    # Process as source
    src_guid = props.get('ProcessGuid') or props.get('SourceProcessGUID')
    if src_guid:
        process_data[src_guid]['events'].append(header.get('task_name'))
        process_data[src_guid]['pid'] = process_data[src_guid]['pid'] or props.get('ProcessId')
        process_data[src_guid]['parent_guid'] = process_data[src_guid]['parent_guid'] or props.get('ParentProcessGuid')
        process_data[src_guid]['parent_pid'] = process_data[src_guid]['parent_pid'] or props.get('ParentProcessId')
        process_data[src_guid]['image'] = process_data[src_guid]['image'] or props.get('Image', '').split('\\')[-1]
        process_data[src_guid]['cmdline'] = process_data[src_guid]['cmdline'] or props.get('CommandLine')
        process_data[src_guid]['user'] = process_data[src_guid]['user'] or props.get('User')
        process_data[src_guid]['integrity'] = process_data[src_guid]['integrity'] or props.get('IntegrityLevel')
        
        timestamp = props.get('UtcTime') or header.get('timestamp')
        if timestamp and timestamp not in process_data[src_guid]['timestamps']:
            process_data[src_guid]['timestamps'].append(timestamp)
    
    # Target processes (for terminated events)
    target_guid = props.get('TargetProcessGUID')
    if target_guid:
        process_data[target_guid]['events'].append(f"Target: {header.get('task_name')}")
    
    # Check for termination event (Event ID 5)
    if 'ProcessTerminate' in header.get('task_name', ''):
        term_guid = props.get('ProcessGuid')
        if term_guid:
            process_data[term_guid]['terminated'] = True

# Convert to regular dict with GUIDs as keys
processes = {guid: data for guid, data in process_data.items() if data['image']}

print(f"Collected {len(processes)} unique processes from Sysmon events")

# Link children
for guid, info in processes.items():
    parent_guid = info['parent_guid']
    if parent_guid and parent_guid in processes:
        processes[parent_guid]['children'].append(guid)

# Print tree
def print_tree(guid, indent=0, visited=set()):
    if guid in visited or guid not in processes:
        return
    visited.add(guid)
    info = processes[guid]
    
    term_flag = "💀" if info['terminated'] else ""
    event_count = len(set(info['events']))
    
    print(f"{'  ' * indent}├─ {info['image']} (PID: {info['pid']}, {info['user']}, {info['integrity']}) {term_flag}")
    if info['cmdline']:
        print(f"{'  ' * indent}│  └─ {info['cmdline'][:100]}")
    print(f"{'  ' * indent}│  └─ Events: {event_count} types | Timestamps: {len(info['timestamps'])}")
    
    for child_guid in info['children']:
        print_tree(child_guid, indent + 1, visited)

# Find roots
roots = [g for g, info in processes.items() if info['parent_guid'] not in processes]

print(f"\nProcess Tree ({len(processes)} processes, {len(roots)} roots):")
print("Legend: 💀 = Terminated\n")

for root in sorted(roots, key=lambda g: min(processes[g]['timestamps']) if processes[g]['timestamps'] else ''):
    print_tree(root)

# Statistics
print(f"\n{'='*70}")
print("STATISTICS")
print(f"{'='*70}")
print(f"Total processes:     {len(processes)}")
print(f"Terminated:          {sum(1 for p in processes.values() if p['terminated'])}")
print(f"Avg events/process:  {sum(len(set(p['events'])) for p in processes.values()) / len(processes):.1f}")
# Out:
# ======================================================================
# SYSMON COMPLETE VIEW (Multi-Event Consolidation)
# ======================================================================
#
# [*] Found 602 matching events
# [*] Showing first 20 of 602 results
#   1. [2025-10-30 03:47:28Z] PID:3856 - File created (rule: FileCreate)
#   2. [2025-10-30 03:47:28Z] PID:3856 - File created (rule: FileCreate)
#   3. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   4. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   5. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   6. [2025-10-30 03:47:28Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   7. [2025-10-30 03:47:28Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   8. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   9. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   10. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   11. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   12. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   13. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   14. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   15. [2025-10-30 03:47:28Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   16. [2025-10-30 03:47:28Z] PID:3856 - Registry object added or deleted (rule: RegistryEvent)
#   17. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   18. [2025-10-30 03:47:28Z] PID:3856 - Process accessed (rule: ProcessAccess)
#   19. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#   20. [2025-10-30 03:47:28Z] PID:3856 - Image loaded (rule: ImageLoad)
#
# ... and 582 more results not displayed
# Collected 24 unique processes from Sysmon events
#
# Process Tree (24 processes, 19 roots):
# Legend: 💀 = Terminated
#
# ├─ System (PID: 4, NT AUTHORITY\SYSTEM, None)
# │  └─ Events: 2 types | Timestamps: 2
# ├─ sealighter.exe (PID: 7660, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 3 types | Timestamps: 12
# ├─ SearchProtocolHost.exe (PID: 5532, DESKTOP-3AERCN7\cyb3r, None) 💀
# │  └─ Events: 2 types | Timestamps: 1
# ├─ Sysmon64.exe (PID: 3856, NT AUTHORITY\SYSTEM, None)
# │  └─ Events: 4 types | Timestamps: 9
# ├─ Explorer.EXE (PID: 4496, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 3 types | Timestamps: 26
# ├─ cmd.exe (PID: 2176, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 3 types | Timestamps: 3
#   ├─ NSec-Killer.exe (PID: 6872, DESKTOP-3AERCN7\cyb3r, High)
#   │  └─ NSec-Killer.exe  -n msmpeng.exe
#   │  └─ Events: 3 types | Timestamps: 5
# ├─ MsMpEng.exe (PID: 2648, NT AUTHORITY\SYSTEM, None) 💀
# │  └─ Events: 9 types | Timestamps: 11
# ├─ services.exe (PID: 652, NT AUTHORITY\SYSTEM, None)
# │  └─ Events: 3 types | Timestamps: 5
#   ├─ MsMpEng.exe (PID: 756, NT AUTHORITY\SYSTEM, System) 💀
#   │  └─ "C:\Program Files\Windows Defender\MsMpEng.exe"
#   │  └─ Events: 8 types | Timestamps: 16
# ├─ svchost.exe (PID: 2144, NT AUTHORITY\LOCAL SERVICE, None)
# │  └─ Events: 1 types | Timestamps: 5
# ├─ ctfmon.exe (PID: 4200, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 3 types | Timestamps: 12
# ├─ svchost.exe (PID: 1640, NT AUTHORITY\SYSTEM, None)
# │  └─ Events: 3 types | Timestamps: 7
# ├─ cmd.exe (PID: 7224, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 4 types | Timestamps: 5
#   ├─ sc.exe (PID: 4432, DESKTOP-3AERCN7\cyb3r, High) 💀
#   │  └─ sc  create changed_to_exe type = kernel binpath=C:\Users\cyb3r\Downloads\Sysnom.exe
#   │  └─ Events: 4 types | Timestamps: 3
#   ├─ sc.exe (PID: 272, DESKTOP-3AERCN7\cyb3r, High) 💀
#   │  └─ sc  create changed_to_exe type=kernel binpath=C:\Users\cyb3r\Downloads\Sysnom.exe
#   │  └─ Events: 4 types | Timestamps: 3
#   ├─ sc.exe (PID: 4636, DESKTOP-3AERCN7\cyb3r, High) 💀
#   │  └─ sc  start changed_to_exe
#   │  └─ Events: 4 types | Timestamps: 3
# ├─ vmtoolsd.exe (PID: 2816, NT AUTHORITY\SYSTEM, None)
# │  └─ Events: 1 types | Timestamps: 4
# ├─ svchost.exe (PID: 2496, NT AUTHORITY\LOCAL SERVICE, None)
# │  └─ Events: 3 types | Timestamps: 2
# ├─ cmd.exe (PID: 5172, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 5 types | Timestamps: 1
# ├─ svchost.exe (PID: 3812, NT AUTHORITY\SYSTEM, None) 💀
# │  └─ Events: 5 types | Timestamps: 3
# ├─ SearchFilterHost.exe (PID: 7952, NT AUTHORITY\SYSTEM, Medium)
# │  └─ "C:\Windows\system32\SearchFilterHost.exe" 0 800 804 812 8192 808 784
# │  └─ Events: 3 types | Timestamps: 3
# ├─ wmiprvse.exe (PID: 1536, NT AUTHORITY\SYSTEM, None)
# │  └─ Events: 1 types | Timestamps: 1
# ├─ cmd.exe (PID: 7328, DESKTOP-3AERCN7\cyb3r, None)
# │  └─ Events: 2 types | Timestamps: 1
#
# ======================================================================
# STATISTICS
# ======================================================================
# Total processes:     24
# Terminated:          7
# Avg events/process:  3.5
